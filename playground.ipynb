# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import time
from datetime import datetime

# %%
# %time  print(datetime.now())
# %time time.sleep(3) 
# %time print(datetime.now())
# Out:
# 2022-10-20 11:59:40.097411
# CPU times: user 400 µs, sys: 50 µs, total: 450 µs
# Wall time: 272 µs
# CPU times: user 2.73 ms, sys: 337 µs, total: 3.06 ms
# Wall time: 3 s
# 2022-10-20 11:59:43.103270
# CPU times: user 121 µs, sys: 15 µs, total: 136 µs
# Wall time: 142 µs

# %%
# %%time
print(datetime.now())
time.sleep(3) 
print(datetime.now())
# Out:
# 2022-10-20 11:57:31.713276
# 2022-10-20 11:57:34.714957
# CPU times: user 0 ns, sys: 5.2 ms, total: 5.2 ms
# Wall time: 3 s

# %%
lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
save?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = sns.load_dataset("tips")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %autosave??

# %%
import pandas as pd
# on windows you might have to add parameter encoding='cp1252' instead of the utf8 default
df = pd.read_csv ('https://apis.hub.db.de/db/apis/dbn-betriebsstellen-csv-cnp-v1/betriebsstellen-csv',encoding='cp1252', on_bad_lines='skip',delimiter=';')

# %%
pd.read_csv?

# %%
df.head()
# Out:
#        PLC RL100-Code              RL100-Langname    RL100-Kurzname Typ Kurz  \
# 0  DE20176        WTG                 Tangersdorf       Tangersdorf       HP
# 1      NaN      WTG A         Tangersdorf Abzweig  Tangersdorf Abzw     BUSH
# 2      NaN      WTG B           Tangersdorf Mitte  Tangersdorf Mitt     BUSH
# 3  DE20308        WTH                Trassenheide      Trassenheide       BF
# 4      NaN      WTH K  Trassenheide Kurverwaltung  Trassenh Kurvwtg     BUSH
#
#   Typ Lang Betriebszustand  Datum ab  Datum bis  Niederlassung  \
# 0       Hp            a.B.  20200401        NaN              1
# 1     Bush         Betrieb  19990101        NaN              0
# 2     Bush         Betrieb  19990101        NaN              0
# 3       Bf         Betrieb  20081214        NaN              0
# 4     Bush             NaN  20220310        NaN              0
#
#   Regionalbereich  Bahnstellen-Nr.  Netzschlüssel  Letzte Änderung
# ...

# %%
# !conda install -c conda-forge rise jupyterlab-git -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupyterlab-git
#     - rise
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gitdb-4.0.9                |     pyhd8ed1ab_0          46 KB  conda-forge
#     gitpython-3.1.29           |     pyhd8ed1ab_0         124 KB  conda-forge
#     jupyter-server-mathjax-0.2.6|     pyhc268e32_0         2.3 MB  conda-forge
#     jupyterlab-git-0.39.3      |     pyhd8ed1ab_0         923 KB  conda-forge
#     nbdime-3.1.1               |     pyhd8ed1ab_0         4.4 MB  conda-forge
#     rise-5.7.1                 |   py39hf3d152e_1         2.6 MB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     ------------------------------------------------------------
# ...
